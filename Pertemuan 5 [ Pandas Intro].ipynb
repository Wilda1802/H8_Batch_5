# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv")

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# 1                1            0     NYK     Knicks  ...  41.705170     TRH
# 2                1            0     CHS      Stags  ...  42.012257     NYK
# 3                2            0     NYK     Knicks  ...  40.692783     CHS
# 4                1            0     DTF    Falcons  ...  38.864048     WSC
# ...            ...          ...     ...        ...  ...        ...     ...
# 126309         100            1     CLE  Cavaliers  ...  60.309792     GSW
# 126310         102            1     GSW   Warriors  ...  68.013329     CLE
# 126311         101            1     CLE  Cavaliers  ...  60.010067     GSW
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# 0          Knicks       68  1300.0000  1306.7233              H            L
# 1         Huskies       66  1300.0000  1293.2767              A            W
# 2          Knicks       47  1306.7233  1297.0712              H            W
# 3           Stags       63  1300.0000  1309.6521              A            L
# 4        Capitols       50  1300.0000  1320.3811              H            L
# ...           ...      ...        ...        ...            ...          ...
# 126309   Warriors      103  1790.9591  1809.9791              H            L
# 126310  Cavaliers       91  1704.3949  1700.7391              H            W
# 126311   Warriors      104  1809.9791  1813.6349              A            L
# 126312   Warriors      105  1813.6349  1822.2881              H            L
# 126313  Cavaliers       97  1700.7391  1692.0859              A            W
#
#         forecast notes
# 0       0.640065   NaN
# 1       0.359935   NaN
# 2       0.631101   NaN
# 3       0.368899   NaN
# 4       0.640065   NaN
# ...          ...   ...
# 126309  0.546572   NaN
# 126310  0.765565   NaN
# 126311  0.234435   NaN
# 126312  0.481450   NaN
# 126313  0.518550   NaN
#
# [126314 rows x 23 columns]

# %%
len(df)
# Out:
# 126314

# %%
df.shape
# Out:
# (126314, 23)

# %%
df.head(20)
# Out:
#     gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0           1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1           1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2           2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3           2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4           3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5           3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6           4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7           4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8           5  194611020STB   NBA        1     1947  11/2/1946           1
# 9           5  194611020STB   NBA        0     1947  11/2/1946           1
# 10          6  194611030CLR   NBA        1     1947  11/3/1946           2
# 11          6  194611030CLR   NBA        0     1947  11/3/1946           1
# 12          7  194611040PIT   NBA        0     1947  11/4/1946           2
# 13          7  194611040PIT   NBA        1     1947  11/4/1946           2
# 14          8  194611050BOS   NBA        0     1947  11/5/1946           2
# 15          8  194611050BOS   NBA        1     1947  11/5/1946           2
# 16          9  194611050DTF   NBA        1     1947  11/5/1946           2
# 17          9  194611050DTF   NBA        0     1947  11/5/1946           2
# 18         10  194611070GSW   NBA        1     1947  11/7/1946           3
# 19         10  194611070GSW   NBA        0     1947  11/7/1946           1
#
#     is_playoffs team_id       fran_id  ...  win_equiv  opp_id      opp_fran  \
# 0             0     TRH       Huskies  ...  40.294830     NYK        Knicks
# 1             0     NYK        Knicks  ...  41.705170     TRH       Huskies
# 2             0     CHS         Stags  ...  42.012257     NYK        Knicks
# 3             0     NYK        Knicks  ...  40.692783     CHS         Stags
# 4             0     DTF       Falcons  ...  38.864048     WSC      Capitols
# 5             0     WSC      Capitols  ...  43.135952     DTF       Falcons
# 6             0     BOS       Celtics  ...  40.459381     PRO  Steamrollers
# 7             0     PRO  Steamrollers  ...  41.540619     BOS       Celtics
# 8             0     PIT       Ironmen  ...  40.507980     STB       Bombers
# 9             0     STB       Bombers  ...  41.492020     PIT       Ironmen
# 10            0     TRH       Huskies  ...  39.548164     CLR        Rebels
# 11            0     CLR        Rebels  ...  41.747120     TRH       Huskies
# 12            0     PIT       Ironmen  ...  38.689037     WSC      Capitols
# 13            0     WSC      Capitols  ...  44.946995     PIT       Ironmen
# 14            0     BOS       Celtics  ...  39.785030     CHS         Stags
# 15            0     CHS         Stags  ...  42.686188     BOS       Celtics
# 16            0     STB       Bombers  ...  42.347137     DTF       Falcons
# 17            0     DTF       Falcons  ...  38.011841     STB       Bombers
# 18            0     PIT       Ironmen  ...  38.201401     PHW      Warriors
# 19            0     PHW      Warriors  ...  41.489525     PIT       Ironmen
#
#     opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# 0        68  1300.0000  1306.7233              H            L  0.640065   NaN
# 1        66  1300.0000  1293.2767              A            W  0.359935   NaN
# 2        47  1306.7233  1297.0712              H            W  0.631101   NaN
# 3        63  1300.0000  1309.6521              A            L  0.368899   NaN
# 4        50  1300.0000  1320.3811              H            L  0.640065   NaN
# 5        33  1300.0000  1279.6189              A            W  0.359935   NaN
# 6        59  1300.0000  1305.1542              A            L  0.359935   NaN
# 7        53  1300.0000  1294.8458              H            W  0.640065   NaN
# 8        56  1300.0000  1304.6908              A            L  0.359935   NaN
# 9        51  1300.0000  1295.3092              H            W  0.640065   NaN
# 10       71  1300.0000  1307.1233              A            L  0.351068   NaN
# 11       60  1293.2767  1286.1534              H            W  0.648932   NaN
# 12       71  1320.3811  1337.7448              H            L  0.606189   NaN
# 13       56  1295.3092  1277.9456              A            W  0.393811   NaN
# 14       57  1309.6521  1316.0840              H            L  0.620204   NaN
# 15       55  1294.8458  1288.4139              A            W  0.379796   NaN
# 16       49  1279.6189  1271.4624              A            W  0.393811   NaN
# 17       53  1304.6908  1312.8473              H            L  0.606189   NaN
# 18       81  1300.0000  1304.6670              A            L  0.331236   NaN
# 19       75  1277.9456  1273.2786              H            W  0.668764   NaN
#
# [20 rows x 23 columns]

# %%
df.tail(20)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126294      63148  201505240CLE   NBA        0     2015  5/24/2015
# 126295      63148  201505240CLE   NBA        1     2015  5/24/2015
# 126296      63149  201505250HOU   NBA        1     2015  5/25/2015
# 126297      63149  201505250HOU   NBA        0     2015  5/25/2015
# 126298      63150  201505260CLE   NBA        0     2015  5/26/2015
# 126299      63150  201505260CLE   NBA        1     2015  5/26/2015
# 126300      63151  201505270GSW   NBA        1     2015  5/27/2015
# 126301      63151  201505270GSW   NBA        0     2015  5/27/2015
# 126302      63152  201506040GSW   NBA        1     2015   6/4/2015
# 126303      63152  201506040GSW   NBA        0     2015   6/4/2015
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126305      63153  201506070GSW   NBA        0     2015   6/7/2015
# 126306      63154  201506090CLE   NBA        1     2015   6/9/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126294          95            1     CLE  Cavaliers  ...  60.254032     ATL
# 126295          97            1     ATL      Hawks  ...  49.744450     CLE
# 126296          96            1     GSW   Warriors  ...  67.053963     HOU
# 126297          98            1     HOU    Rockets  ...  56.407814     GSW
# 126298          96            1     CLE  Cavaliers  ...  60.934734     ATL
# 126299          98            1     ATL      Hawks  ...  48.898579     CLE
# 126300          99            1     HOU    Rockets  ...  56.013645     GSW
# 126301          97            1     GSW   Warriors  ...  67.324539     HOU
# 126302          97            1     CLE  Cavaliers  ...  60.616585     GSW
# 126303          98            1     GSW   Warriors  ...  67.566650     CLE
# 126304          98            1     CLE  Cavaliers  ...  61.312763     GSW
# 126305          99            1     GSW   Warriors  ...  67.029549     CLE
# 126306         100            1     GSW   Warriors  ...  66.615417     CLE
# 126307          99            1     CLE  Cavaliers  ...  61.826408     GSW
# 126308         101            1     GSW   Warriors  ...  67.794983     CLE
# 126309         100            1     CLE  Cavaliers  ...  60.309792     GSW
# 126310         102            1     GSW   Warriors  ...  68.013329     CLE
# 126311         101            1     CLE  Cavaliers  ...  60.010067     GSW
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# 126294      Hawks      111  1591.4017  1589.2021              H            W
# 126295  Cavaliers      114  1701.5128  1703.7124              A            L
# 126296    Rockets      128  1643.4324  1658.9934              A            L
# 126297   Warriors      115  1813.4543  1797.8933              H            W
# 126298      Hawks       88  1589.2021  1580.7914              H            W
# 126299  Cavaliers      118  1703.7124  1712.1232              A            L
# 126300   Warriors      104  1797.8933  1802.2509              A            L
# 126301    Rockets       90  1658.9934  1654.6359              H            W
# 126302   Warriors      108  1802.2509  1806.2035              A            L
# 126303  Cavaliers      100  1712.1232  1708.1705              H            W
# 126304   Warriors       93  1806.2035  1797.5032              A            W
# 126305  Cavaliers       95  1708.1705  1716.8708              H            L
# 126306  Cavaliers       96  1716.8708  1723.4149              A            L
# 126307   Warriors       91  1797.5032  1790.9591              H            W
# 126308  Cavaliers       82  1723.4149  1704.3949              A            W
# 126309   Warriors      103  1790.9591  1809.9791              H            L
# 126310  Cavaliers       91  1704.3949  1700.7391              H            W
# 126311   Warriors      104  1809.9791  1813.6349              A            L
# 126312   Warriors      105  1813.6349  1822.2881              H            L
# 126313  Cavaliers       97  1700.7391  1692.0859              A            W
#
#         forecast notes
# 126294  0.770210   NaN
# 126295  0.229790   NaN
# 126296  0.599427   NaN
# 126297  0.400573   NaN
# 126298  0.774661   NaN
# 126299  0.225339   NaN
# 126300  0.201778   NaN
# 126301  0.798222   NaN
# 126302  0.250779   NaN
# 126303  0.749221   NaN
# 126304  0.242326   NaN
# 126305  0.757674   NaN
# 126306  0.472157   NaN
# 126307  0.527843   NaN
# 126308  0.453428   NaN
# 126309  0.546572   NaN
# 126310  0.765565   NaN
# 126311  0.234435   NaN
# 126312  0.481450   NaN
# 126313  0.518550   NaN
#
# [20 rows x 23 columns]

# %%
pd.set_option("display.max.columns",None)
pd.set_option("display.precision",2)

# %%
df.head(20)
# Out:
#     gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0           1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1           1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2           2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3           2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4           3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5           3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6           4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7           4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8           5  194611020STB   NBA        1     1947  11/2/1946           1
# 9           5  194611020STB   NBA        0     1947  11/2/1946           1
# 10          6  194611030CLR   NBA        1     1947  11/3/1946           2
# 11          6  194611030CLR   NBA        0     1947  11/3/1946           1
# 12          7  194611040PIT   NBA        0     1947  11/4/1946           2
# 13          7  194611040PIT   NBA        1     1947  11/4/1946           2
# 14          8  194611050BOS   NBA        0     1947  11/5/1946           2
# 15          8  194611050BOS   NBA        1     1947  11/5/1946           2
# 16          9  194611050DTF   NBA        1     1947  11/5/1946           2
# 17          9  194611050DTF   NBA        0     1947  11/5/1946           2
# 18         10  194611070GSW   NBA        1     1947  11/7/1946           3
# 19         10  194611070GSW   NBA        0     1947  11/7/1946           1
#
#     is_playoffs team_id       fran_id  pts    elo_i    elo_n  win_equiv  \
# 0             0     TRH       Huskies   66  1300.00  1293.28      40.29
# 1             0     NYK        Knicks   68  1300.00  1306.72      41.71
# 2             0     CHS         Stags   63  1300.00  1309.65      42.01
# 3             0     NYK        Knicks   47  1306.72  1297.07      40.69
# 4             0     DTF       Falcons   33  1300.00  1279.62      38.86
# 5             0     WSC      Capitols   50  1300.00  1320.38      43.14
# 6             0     BOS       Celtics   53  1300.00  1294.85      40.46
# 7             0     PRO  Steamrollers   59  1300.00  1305.15      41.54
# 8             0     PIT       Ironmen   51  1300.00  1295.31      40.51
# 9             0     STB       Bombers   56  1300.00  1304.69      41.49
# 10            0     TRH       Huskies   60  1293.28  1286.15      39.55
# 11            0     CLR        Rebels   71  1300.00  1307.12      41.75
# 12            0     PIT       Ironmen   56  1295.31  1277.95      38.69
# 13            0     WSC      Capitols   71  1320.38  1337.74      44.95
# 14            0     BOS       Celtics   55  1294.85  1288.41      39.79
# 15            0     CHS         Stags   57  1309.65  1316.08      42.69
# 16            0     STB       Bombers   53  1304.69  1312.85      42.35
# 17            0     DTF       Falcons   49  1279.62  1271.46      38.01
# 18            0     PIT       Ironmen   75  1277.95  1273.28      38.20
# 19            0     PHW      Warriors   81  1300.00  1304.67      41.49
#
#    opp_id      opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location  \
# 0     NYK        Knicks       68    1300.00    1306.72             H
# 1     TRH       Huskies       66    1300.00    1293.28             A
# 2     NYK        Knicks       47    1306.72    1297.07             H
# 3     CHS         Stags       63    1300.00    1309.65             A
# 4     WSC      Capitols       50    1300.00    1320.38             H
# 5     DTF       Falcons       33    1300.00    1279.62             A
# 6     PRO  Steamrollers       59    1300.00    1305.15             A
# 7     BOS       Celtics       53    1300.00    1294.85             H
# 8     STB       Bombers       56    1300.00    1304.69             A
# 9     PIT       Ironmen       51    1300.00    1295.31             H
# 10    CLR        Rebels       71    1300.00    1307.12             A
# 11    TRH       Huskies       60    1293.28    1286.15             H
# 12    WSC      Capitols       71    1320.38    1337.74             H
# 13    PIT       Ironmen       56    1295.31    1277.95             A
# 14    CHS         Stags       57    1309.65    1316.08             H
# 15    BOS       Celtics       55    1294.85    1288.41             A
# 16    DTF       Falcons       49    1279.62    1271.46             A
# 17    STB       Bombers       53    1304.69    1312.85             H
# 18    PHW      Warriors       81    1300.00    1304.67             A
# 19    PIT       Ironmen       75    1277.95    1273.28             H
#
#    game_result  forecast notes
# 0            L      0.64   NaN
# 1            W      0.36   NaN
# 2            W      0.63   NaN
# 3            L      0.37   NaN
# 4            L      0.64   NaN
# 5            W      0.36   NaN
# 6            L      0.36   NaN
# 7            W      0.64   NaN
# 8            L      0.36   NaN
# 9            W      0.64   NaN
# 10           L      0.35   NaN
# 11           W      0.65   NaN
# 12           L      0.61   NaN
# 13           W      0.39   NaN
# 14           L      0.62   NaN
# 15           W      0.38   NaN
# 16           W      0.39   NaN
# 17           L      0.61   NaN
# 18           L      0.33   NaN
# 19           W      0.67   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
#  17  opp_elo_i      126314 non-null  float64
#  18  opp_elo_n      126314 non-null  float64
#  19  game_location  126314 non-null  object
#  20  game_result    126314 non-null  object
#  21  forecast       126314 non-null  float64
#  22  notes          5424 non-null    object
# dtypes: float64(6), int64(7), object(10)
# memory usage: 22.2+ MB

# %%
df.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# min      1091.64    1085.77      10.15       0.00    1091.64    1085.77
# 25%      1417.24    1416.99      34.10      93.00    1417.24    1416.99
# 50%      1500.95    1500.95      42.11     103.00    1500.95    1500.95
# 75%      1576.06    1576.29      49.64     112.00    1576.06    1576.29
# max      1853.10    1853.10      71.11     186.00    1853.10    1853.10
#
#         forecast
# count  126314.00
# mean        0.50
# std         0.22
# min         0.02
# 25%         0.33
# 50%         0.50
# 75%         0.67
# max         0.98

# %%
df["team_id"].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
len(df["fran_id"].value_counts())
# Out:
# 53

# %%
df["fran_id"].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# Steamrollers     168
# Packers           72
# Redskins          65
# Rebels            63
# Waterloo          62
# Denver            62
# Falcons           60
# Jets              60
# Ironmen           60
# Huskies           60
# Name: fran_id, dtype: int64

# %%
df[df["fran_id"] == "Lakers"]["team_id"].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
(df["fran_id"] == "Lakers").values
# Out:
# array([False, False, False, ..., False, False, False])

# %%
df[df["fran_id"] == "Warriors"]["team_id"].value_counts()
# Out:
# GSW    3701
# PHW    1179
# SFW     777
# Name: team_id, dtype: int64

# %%
df[df["team_id"] == "MNL"]["date_game"].max()
# Out:
# '4/9/1959'

# %%
df[df["team_id"] == "MNL"]["date_game"].min()
# Out:
# '1/1/1949'

# %%
df[df["team_id"] == "MNL"]["date_game"].agg(("min","max"))
# Out:
# min    1/1/1949
# max    4/9/1959
# Name: date_game, dtype: object

# %%
df["team_id"]
# Out:
# 0         TRH
# 1         NYK
# 2         CHS
# 3         NYK
# 4         DTF
#          ...
# 126309    CLE
# 126310    GSW
# 126311    CLE
# 126312    CLE
# 126313    GSW
# Name: team_id, Length: 126314, dtype: object

# %% [markdown]
# ## Series

# %%
s = pd.Series([20000,58790,710])

# %%
s
# Out:
# 0    20000
# 1    58790
# 2      710
# dtype: int64

# %%
s.values
# Out:
# array([20000, 58790,   710], dtype=int64)

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
city_revenue = pd.Series(
    [20000,58790,710],
    index=["purbalingga","pemalang","solo"]
)

# %%
city_revenue
# Out:
# purbalingga    20000
# pemalang       58790
# solo             710
# dtype: int64

# %%
city_revenue.values
# Out:
# array([20000, 58790,   710], dtype=int64)

# %%
city_revenue.index=["purbalingga","pemalang","solo"]

# %%
city_revenue
# Out:
# purbalingga    20000
# pemalang       58790
# solo             710
# dtype: int64

# %%
city_revenue.keys()
# Out:
# Index(['purbalingga', 'pemalang', 'solo'], dtype='object')

# %%
city_manager = pd.Series({"pemalang":15,"solo":5})

# %%
city_manager.index
# Out:
# Index(['pemalang', 'solo'], dtype='object')

# %%
"Semarang"in city_revenue
# Out:
# False

# %%
"solo" in city_revenue
# Out:
# True

# %%
321 in city_revenue
# Out:
# False

# %% [markdown]
# ## Data Frame

# %%
city_revenue
# Out:
# purbalingga    20000
# pemalang       58790
# solo             710
# dtype: int64

# %%
city_manager
# Out:
# pemalang    15
# solo         5
# dtype: int64

# %%
city_data=pd.DataFrame({
    "revenue":city_revenue,
    "manager_count":city_manager
})

# %%
city_data
# Out:
#              revenue  manager_count
# pemalang       58790           15.0
# purbalingga    20000            NaN
# solo             710            5.0

# %%
city_data.values
# Out:
# array([[5.879e+04, 1.500e+01],
#        [2.000e+04,       nan],
#        [7.100e+02, 5.000e+00]])

# %%
city_data.axes
# Out:
# [Index(['pemalang', 'purbalingga', 'solo'], dtype='object'),
#  Index(['revenue', 'manager_count'], dtype='object')]

# %%
city_data.axes[0]
# Out:
# Index(['pemalang', 'purbalingga', 'solo'], dtype='object')

# %%
city_data.axes[1]
# Out:
# Index(['revenue', 'manager_count'], dtype='object')

# %%
"solo" in city_data.index
# Out:
# True

# %%
"revenue" in city_data.columns
# Out:
# True

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
df.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
city_data.loc["solo","revenue"]
# Out:
# 710

# %%
city_revenue.loc["pemalang"]
# Out:
# 58790

# %%
city_revenue
# Out:
# purbalingga    20000
# pemalang       58790
# solo             710
# dtype: int64

# %%
city_revenue.iloc[0:2]
# Out:
# purbalingga    20000
# pemalang       58790
# dtype: int64

# %%
city_revenue.loc["purbalingga":"pemalang"]
# Out:
# purbalingga    20000
# pemalang       58790
# dtype: int64

# %%
city_data
# Out:
#              revenue  manager_count
# pemalang       58790           15.0
# purbalingga    20000            NaN
# solo             710            5.0

# %%
s2 = pd.Series(
    ['h','i','j','k','l','m','n'],
    index=[1,6,3,4,5,2,7]
)

# %%
s2.loc[6]
# Out:
# 'i'

# %%
s2.iloc[0:8]
# Out:
# 1    h
# 6    i
# 3    j
# 4    k
# 5    l
# 2    m
# 7    n
# dtype: object

# %%
s2.iloc[:6]
# Out:
# 1    h
# 6    i
# 3    j
# 4    k
# 5    l
# 2    m
# dtype: object

# %%
city_data["revenue"]['purbalingga']
# Out:
# 20000

# %%
city_data.loc["purbalingga":"solo",:]
# Out:
#              revenue  manager_count
# purbalingga    20000            NaN
# solo             710            5.0

# %%
city_data.iloc[0:2,:]
# Out:
#              revenue  manager_count
# pemalang       58790           15.0
# purbalingga    20000            NaN

# %% [markdown]
# ## Querying

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# 1                1            0     NYK     Knicks   68  1300.00  1306.72
# 2                1            0     CHS      Stags   63  1300.00  1309.65
# 3                2            0     NYK     Knicks   47  1306.72  1297.07
# 4                1            0     DTF    Falcons   33  1300.00  1279.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 0           40.29    NYK     Knicks       68    1300.00    1306.72
# 1           41.71    TRH    Huskies       66    1300.00    1293.28
# 2           42.01    NYK     Knicks       47    1306.72    1297.07
# 3           40.69    CHS      Stags       63    1300.00    1309.65
# 4           38.86    WSC   Capitols       50    1300.00    1320.38
# ...           ...    ...        ...      ...        ...        ...
# 126309      60.31    GSW   Warriors      103    1790.96    1809.98
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 0                  H           L      0.64   NaN
# 1                  A           W      0.36   NaN
# 2                  H           W      0.63   NaN
# 3                  A           L      0.37   NaN
# 4                  H           L      0.64   NaN
# ...              ...         ...       ...   ...
# 126309             H           L      0.55   NaN
# 126310             H           W      0.77   NaN
# 126311             A           L      0.23   NaN
# 126312             H           L      0.48   NaN
# 126313             A           W      0.52   NaN
#
# [126314 rows x 23 columns]

# %%
df[df["fran_id"] == "Warriors"]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 19             10  194611070GSW   NBA        0     1947   11/7/1946
# 44             23  194611140GSW   NBA        0     1947  11/14/1946
# 66             34  194611190GSW   NBA        0     1947  11/19/1946
# 78             40  194611210GSW   NBA        0     1947  11/21/1946
# 102            52  194611260GSW   NBA        0     1947  11/26/1946
# ...           ...           ...   ...      ...      ...         ...
# 126305      63153  201506070GSW   NBA        0     2015    6/7/2015
# 126306      63154  201506090CLE   NBA        1     2015    6/9/2015
# 126308      63155  201506110CLE   NBA        1     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id   fran_id  pts    elo_i    elo_n  \
# 19               1            0     PHW  Warriors   81  1300.00  1304.67
# 44               2            0     PHW  Warriors   68  1304.67  1308.66
# 66               3            0     PHW  Warriors   63  1308.66  1301.04
# 78               4            0     PHW  Warriors   63  1301.04  1294.76
# 102              5            0     PHW  Warriors   66  1294.76  1300.63
# ...            ...          ...     ...       ...  ...      ...      ...
# 126305          99            1     GSW  Warriors   93  1806.20  1797.50
# 126306         100            1     GSW  Warriors   91  1797.50  1790.96
# 126308         101            1     GSW  Warriors  103  1790.96  1809.98
# 126310         102            1     GSW  Warriors  104  1809.98  1813.63
# 126313         103            1     GSW  Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 19          41.49    PIT    Ironmen       75    1277.95    1273.28
# 44          41.91    WSC   Capitols       65    1320.63    1316.64
# 66          41.11    STB    Bombers       66    1315.33    1322.95
# 78          40.45    CHS      Stags       65    1323.82    1330.09
# 102         41.07    BOS    Celtics       54    1234.66    1228.79
# ...           ...    ...        ...      ...        ...        ...
# 126305      67.03    CLE  Cavaliers       95    1708.17    1716.87
# 126306      66.62    CLE  Cavaliers       96    1716.87    1723.41
# 126308      67.79    CLE  Cavaliers       82    1723.41    1704.39
# 126310      68.01    CLE  Cavaliers       91    1704.39    1700.74
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 19                 H           W      0.67   NaN
# 44                 H           W      0.62   NaN
# 66                 H           L      0.63   NaN
# 78                 H           L      0.61   NaN
# 102                H           W      0.72   NaN
# ...              ...         ...       ...   ...
# 126305             H           L      0.76   NaN
# 126306             A           L      0.47   NaN
# 126308             A           W      0.45   NaN
# 126310             H           W      0.77   NaN
# 126313             A           W      0.52   NaN
#
# [5657 rows x 23 columns]

# %%
nba_2010s = df[df["year_id"]>2010]

# %%
nba_2010s.head()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
#
#         seasongame  is_playoffs team_id  fran_id  pts    elo_i    elo_n  \
# 113656           1            0     MIA     Heat   80  1547.36  1543.16
# 113657           1            0     BOS  Celtics   88  1625.10  1629.30
# 113658           1            0     HOU  Rockets  110  1504.20  1502.60
# 113659           1            0     LAL   Lakers  112  1647.60  1649.20
# 113660           1            0     PHO     Suns   92  1643.02  1630.62
#
#         win_equiv opp_id      opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 113656      45.14    BOS       Celtics       88    1625.10    1629.30
# 113657      53.75    MIA          Heat       80    1547.36    1543.16
# 113658      40.90    LAL        Lakers      112    1647.60    1649.20
# 113659      55.61    HOU       Rockets      110    1504.20    1502.60
# 113660      53.88    POR  Trailblazers      106    1552.81    1565.22
#
#        game_location game_result  forecast notes
# 113656             A           L      0.26   NaN
# 113657             H           W      0.74   NaN
# 113658             A           L      0.20   NaN
# 113659             H           W      0.80   NaN
# 113660             A           L      0.49   NaN

# %%
nba_2010s.shape
# Out:
# (12658, 23)

# %%
nba_2010s[["team_id","fran_id"]].nunique()
# Out:
# team_id    33
# fran_id    30
# dtype: int64

# %%
game_with_notes = df[df["notes"].notna()]

# %%
game_with_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# 930             28            0     WSC      Capitols   71  1469.35  1454.90
# 931             31            0     BLB     Baltimore   95  1434.05  1448.50
# 1084            49            1     WSC      Capitols   70  1465.90  1461.20
# 1085            49            1     CHS         Stags   74  1440.72  1445.42
# 1088            49            1     BLB     Baltimore   75  1477.26  1484.31
# ...            ...          ...     ...           ...  ...      ...      ...
# 122207          39            0     ATL         Hawks  110  1505.05  1487.59
# 123916           8            0     HOU       Rockets  113  1635.77  1642.45
# 123917           7            0     MIN  Timberwolves  101  1502.92  1496.24
# 124862          40            0     MIL         Bucks   95  1499.90  1505.86
# 124863          41            0     NYK        Knicks   79  1304.46  1298.50
#
#         win_equiv opp_id      opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 930         47.07    BLB     Baltimore       95    1434.05    1448.50
# 931         46.41    WSC      Capitols       71    1469.35    1454.90
# 1084        47.71    CHS         Stags       74    1440.72    1445.42
# 1085        46.09    WSC      Capitols       70    1465.90    1461.20
# 1088        50.04    CHS         Stags       72    1445.42    1438.36
# ...           ...    ...           ...      ...        ...        ...
# 122207      39.24    BRK          Nets      127    1454.65    1472.11
# 123916      54.89    MIN  Timberwolves      101    1502.92    1496.24
# 123917      40.13    HOU       Rockets      113    1635.77    1642.45
# 124862      41.14    NYK        Knicks       79    1304.46    1298.50
# 124863      21.19    MIL         Bucks       95    1499.90    1505.86
#
#        game_location game_result  forecast  \
# 930                A           L      0.41
# 931                H           W      0.59
# 1084               A           L      0.39
# 1085               H           W      0.61
# 1088               A           W      0.40
# ...              ...         ...       ...
# 122207             N           L      0.57
# 123916             N           W      0.68
# 123917             N           L      0.32
# 124862             N           W      0.75
# 124863             N           L      0.25
#
#                                             notes
# 930          at Baltimore's Fifth Regiment Armory
# 931          at Baltimore's Fifth Regiment Armory
# 1084                                   Tiebreaker
# 1085                                   Tiebreaker
# 1088                                   Tiebreaker
# ...                                           ...
# 122207                         at London, England
# 123916  at Mexico City Arena, Mexico City, Mexico
# 123917  at Mexico City Arena, Mexico City, Mexico
# 124862                 at The O2, London, England
# 124863                 at The O2, London, England
#
# [5424 rows x 23 columns]

# %%
df[df["fran_id"].str.endswith("ks")]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1               1  194611010TRH   NBA        1     1947   11/1/1946
# 3               2  194611020CHS   NBA        1     1947   11/2/1946
# 23             12  194611070STB   NBA        1     1947   11/7/1946
# 37             19  194611110NYK   NBA        0     1947  11/11/1946
# 54             28  194611160NYK   NBA        0     1947  11/16/1946
# ...           ...           ...   ...      ...      ...         ...
# 126279      63140  201505150WAS   NBA        1     2015   5/15/2015
# 126286      63144  201505200ATL   NBA        0     2015   5/20/2015
# 126290      63146  201505220ATL   NBA        0     2015   5/22/2015
# 126295      63148  201505240CLE   NBA        1     2015   5/24/2015
# 126299      63150  201505260CLE   NBA        1     2015   5/26/2015
#
#         seasongame  is_playoffs team_id fran_id  pts    elo_i    elo_n  \
# 1                1            0     NYK  Knicks   68  1300.00  1306.72
# 3                2            0     NYK  Knicks   47  1306.72  1297.07
# 23               3            0     NYK  Knicks   68  1297.07  1307.32
# 37               4            0     NYK  Knicks   68  1307.32  1293.22
# 54               5            0     NYK  Knicks   64  1293.22  1296.22
# ...            ...          ...     ...     ...  ...      ...      ...
# 126279          94            1     ATL   Hawks   94  1607.39  1613.94
# 126286          95            1     ATL   Hawks   89  1613.94  1603.66
# 126290          96            1     ATL   Hawks   82  1603.66  1591.40
# 126295          97            1     ATL   Hawks  111  1591.40  1589.20
# 126299          98            1     ATL   Hawks   88  1589.20  1580.79
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 1           41.71    TRH    Huskies       66    1300.00    1293.28
# 3           40.69    CHS      Stags       63    1300.00    1309.65
# 23          41.77    STB    Bombers       63    1312.85    1302.60
# 37          40.29    CHS      Stags       78    1315.25    1329.36
# 54          40.60    PIT    Ironmen       62    1277.56    1274.56
# ...           ...    ...        ...      ...        ...        ...
# 126279      52.19    WAS    Wizards       91    1552.66    1546.10
# 126286      51.18    CLE  Cavaliers       97    1678.98    1689.25
# 126290      49.96    CLE  Cavaliers       94    1689.25    1701.51
# 126295      49.74    CLE  Cavaliers      114    1701.51    1703.71
# 126299      48.90    CLE  Cavaliers      118    1703.71    1712.12
#
#        game_location game_result  forecast notes
# 1                  A           W      0.36   NaN
# 3                  A           L      0.37   NaN
# 23                 A           W      0.34   NaN
# 37                 H           L      0.63   NaN
# 54                 H           W      0.66   NaN
# ...              ...         ...       ...   ...
# 126279             A           W      0.44   NaN
# 126286             H           L      0.55   NaN
# 126290             H           L      0.52   NaN
# 126295             A           L      0.23   NaN
# 126299             A           L      0.23   NaN
#
# [18388 rows x 23 columns]

# %%
df[df["_iscopy"]==0]["game_location"].value_counts()
# Out:
# H    63138
# N       19
# Name: game_location, dtype: int64

# %%
df[
    (df["_iscopy"] == 0) & 
    (df["pts"] > 100) &
    (df['game_result'] == "L")&
    (~df["notes"].isna())
]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1449          725  194901040PRO   NBA        0     1949    1/4/1949
# 5208         2605  195303110BLB   NBA        0     1953   3/11/1953
# 5825         2913  195402220BLB   NBA        0     1954   2/22/1954
# 6191         3096  195412290BOS   NBA        0     1955  12/29/1954
# 6322         3162  195501250NYK   NBA        0     1955   1/25/1955
# ...           ...           ...   ...      ...      ...         ...
# 102319      51160  200603080NOK   NBA        0     2006    3/8/2006
# 105201      52601  200703230NOK   NBA        0     2007   3/23/2007
# 115504      57753  201103050NJN   NBA        0     2011    3/5/2011
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# 1449            27            0     PRO  Steamrollers  104  1193.82  1189.41
# 5208            66            0     BLB     Baltimore  107  1284.52  1282.24
# 5825            60            0     BLB     Baltimore  110  1303.75  1301.97
# 6191            27            0     BOS       Celtics  118  1565.80  1551.04
# 6322            42            0     NYK        Knicks  104  1527.65  1519.86
# ...            ...          ...     ...           ...  ...      ...      ...
# 102319          60            0     NOK      Pelicans  107  1484.56  1475.08
# 105201          69            0     NOK      Pelicans  105  1460.75  1450.60
# 115504          63            0     TOR       Raptors  136  1324.53  1320.72
# 122207          39            0     ATL         Hawks  110  1505.05  1487.59
# 123917           7            0     MIN  Timberwolves  101  1502.92  1496.24
#
#         win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 1449        17.61    CHS    Stags      115    1500.41    1504.82
# 5208        19.58    NYK   Knicks      113    1649.15    1651.44
# 5825        20.74    BOS  Celtics      111    1591.49    1593.27
# 6191        42.73    MNL   Lakers      129    1578.28    1593.04
# 6322        39.46    ROC    Kings      107    1527.00    1534.80
# ...           ...    ...      ...      ...        ...        ...
# 102319      38.51    LAL   Lakers      113    1525.75    1535.22
# 105201      35.80    LAL   Lakers      111    1480.02    1490.17
# 115504      23.11    NJN     Nets      137    1340.41    1344.22
# 122207      39.24    BRK     Nets      127    1454.65    1472.11
# 123917      40.13    HOU  Rockets      113    1635.77    1642.45
#
#        game_location game_result  forecast  \
# 1449               H           L      0.23
# 5208               H           L      0.18
# 5825               H           L      0.25
# 6191               H           L      0.62
# 6322               H           L      0.64
# ...              ...         ...       ...
# 102319             H           L      0.58
# 105201             H           L      0.61
# 115504             N           L      0.48
# 122207             N           L      0.57
# 123917             N           L      0.32
#
#                                             notes
# 1449                                 at Boston MA
# 5208                                 at Boston MA
# 5825                              at Worcester MA
# 6191                                at Hibbing MN
# 6322                                at Buffalo NY
# ...                                           ...
# 102319                         at New Orleans, LA
# 105201                         at New Orleans, LA
# 115504                         at London, England
# 122207                         at London, England
# 123917  at Mexico City Arena, Mexico City, Mexico
#
# [699 rows x 23 columns]

# %% [markdown]
# ## Agregasi

# %%
df[df["team_id"] == "BOS"]["pts"].sum()
# Out:
# 626484

# %%
df[df["team_id"] == "BOS"].groupby("year_id")["game_id"].nunique()
# Out:
# year_id
# 1947    60
# 1948    51
# 1949    60
# 1950    68
# 1951    71
#         ..
# 2011    91
# 2012    86
# 2013    87
# 2014    82
# 2015    86
# Name: game_id, Length: 69, dtype: int64

# %%
df.groupby("fran_id")["pts"].mean()
# Out:
# fran_id
# Baltimore        79.70
# Bombers          71.46
# Bucks           103.70
# Bulls           101.53
# Capitols         76.93
# Cavaliers        99.85
# Celtics         104.47
# Clippers        101.93
# Colonels        111.63
# Condors         115.45
# Denver           77.71
# Falcons          63.28
# Floridians      112.65
# Grizzlies        95.16
# Hawks           101.81
# Heat             96.63
# Hornets          94.51
# Huskies          66.58
# Ironmen          61.23
# Jazz            102.15
# Jets             74.70
# Kings           103.97
# Knicks          100.97
# Lakers          105.82
# Magic            99.43
# Mavericks       102.63
# Nets            101.76
# Nuggets         108.20
# Olympians        81.08
# Pacers          103.69
# Packers          86.01
# Pelicans         97.96
# Pistons         101.37
# Raptors          96.92
# Rebels           71.02
# Redskins         82.65
# Rockets         104.12
# Sails           109.78
# Sixers          103.81
# Sounds          108.44
# Spirits         110.52
# Spurs           105.32
# Squires         114.05
# Stags            78.45
# Stars           112.35
# Steamrollers     73.64
# Suns            107.23
# Thunder         104.77
# Timberwolves     97.46
# Trailblazers    104.06
# Warriors        104.51
# Waterloo         79.37
# Wizards         103.62
# Name: pts, dtype: float64

# %%
df[
    (df["team_id"] == "BOS") &
    (df["year_id"] > 2010)
].groupby(["year_id","game_result"])["pts"].mean()
# Out:
# year_id  game_result
# 2011     L               86.60
#          W              101.10
# 2012     L               85.81
#          W               95.26
# 2013     L               89.84
#          W              101.37
# 2014     L               93.05
#          W              103.52
# 2015     L               98.41
#          W              104.10
# Name: pts, dtype: float64

# %%
df[
    (df["team_id"] == "BOS") &
    (df["year_id"] > 2010)
].groupby(["year_id","is_playoffs","game_result"])["pts"].mean()
# Out:
# year_id  is_playoffs  game_result
# 2011     0            L               86.15
#                       W              101.30
#          1            L               89.50
#                       W               98.80
# 2012     0            L               86.41
#                       W               95.62
#          1            L               84.00
#                       W               94.00
# 2013     0            L               91.20
#                       W              101.71
#          1            L               76.25
#                       W               94.50
# 2014     0            L               93.05
#                       W              103.52
# 2015     0            L               98.76
#                       W              104.10
#          1            L               94.75
# Name: pts, dtype: float64

# %%
nba = df.copy()

# %%
nba["pts_diff"] = nba["pts"] - nba["opp_pts"]

# %%
nba["pts_diff"] = np.abs(nba["pts"]-nba["opp_pts"])

# %%
nba["pts_diff"].agg(("min","max"))
# Out:
# min     1
# max    68
# Name: pts_diff, dtype: int64

# %%
nba = nba.rename(columns={"game_result":"result","game_location":"location"})

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n location result  forecast notes  \
# 0    Knicks       68    1300.00    1306.72        H      L      0.64   NaN
# 1   Huskies       66    1300.00    1293.28        A      W      0.36   NaN
# 2    Knicks       47    1306.72    1297.07        H      W      0.63   NaN
# 3     Stags       63    1300.00    1309.65        A      L      0.37   NaN
# 4  Capitols       50    1300.00    1320.38        H      L      0.64   NaN
#
#    pts_diff
# 0         2
# 1         2
# 2        16
# 3        16
# 4        17

# %%
drop_columns = ["lg_id","elo_i","elo_n","opp_elo_i","opp_elo_n"]
nba.drop(drop_columns,inplace= True, axis=1)

# %%
nba.shape
# Out:
# (126314, 19)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   _iscopy      126314 non-null  int64
#  3   year_id      126314 non-null  int64
#  4   date_game    126314 non-null  object
#  5   seasongame   126314 non-null  int64
#  6   is_playoffs  126314 non-null  int64
#  7   team_id      126314 non-null  object
#  8   fran_id      126314 non-null  object
#  9   pts          126314 non-null  int64
#  10  win_equiv    126314 non-null  float64
#  11  opp_id       126314 non-null  object
#  12  opp_fran     126314 non-null  object
#  13  opp_pts      126314 non-null  int64
#  14  location     126314 non-null  object
#  15  result       126314 non-null  object
#  16  forecast     126314 non-null  float64
#  17  notes        5424 non-null    object
#  18  pts_diff     126314 non-null  int64
# dtypes: float64(2), int64(8), object(9)
# memory usage: 18.3+ MB

# %%
nba["data_game"] = pd.to_datetime(nba["date_game"])

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   _iscopy      126314 non-null  int64
#  3   year_id      126314 non-null  int64
#  4   date_game    126314 non-null  object
#  5   seasongame   126314 non-null  int64
#  6   is_playoffs  126314 non-null  int64
#  7   team_id      126314 non-null  object
#  8   fran_id      126314 non-null  object
#  9   pts          126314 non-null  int64
#  10  win_equiv    126314 non-null  float64
#  11  opp_id       126314 non-null  object
#  12  opp_fran     126314 non-null  object
#  13  opp_pts      126314 non-null  int64
#  14  location     126314 non-null  object
#  15  result       126314 non-null  object
#  16  forecast     126314 non-null  float64
#  17  notes        5424 non-null    object
#  18  pts_diff     126314 non-null  int64
#  19  data_game    126314 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(8), object(9)
# memory usage: 19.3+ MB

# %%
nba['location'] = pd.Categorical(nba['location'])

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   _iscopy      126314 non-null  int64
#  3   year_id      126314 non-null  int64
#  4   date_game    126314 non-null  object
#  5   seasongame   126314 non-null  int64
#  6   is_playoffs  126314 non-null  int64
#  7   team_id      126314 non-null  object
#  8   fran_id      126314 non-null  object
#  9   pts          126314 non-null  int64
#  10  win_equiv    126314 non-null  float64
#  11  opp_id       126314 non-null  object
#  12  opp_fran     126314 non-null  object
#  13  opp_pts      126314 non-null  int64
#  14  location     126314 non-null  category
#  15  result       126314 non-null  object
#  16  forecast     126314 non-null  float64
#  17  notes        5424 non-null    object
#  18  pts_diff     126314 non-null  int64
#  19  data_game    126314 non-null  datetime64[ns]
# dtypes: category(1), datetime64[ns](1), float64(2), int64(8), object(8)
# memory usage: 18.4+ MB

# %%
nba.dropna()
# Out:
#         gameorder       game_id  _iscopy  year_id   date_game  seasongame  \
# 930           466  194801300BLB        1     1948   1/30/1948          28
# 931           466  194801300BLB        0     1948   1/30/1948          31
# 1084          543  194803230CHS        1     1948   3/23/1948          49
# 1085          543  194803230CHS        0     1948   3/23/1948          49
# 1088          545  194803250CHS        1     1948   3/25/1948          49
# ...           ...           ...      ...      ...         ...         ...
# 122207      61104  201401160ATL        0     2014   1/16/2014          39
# 123916      61959  201411120MIN        1     2015  11/12/2014           8
# 123917      61959  201411120MIN        0     2015  11/12/2014           7
# 124862      62432  201501150MIL        0     2015   1/15/2015          40
# 124863      62432  201501150MIL        1     2015   1/15/2015          41
#
#         is_playoffs team_id       fran_id  pts  win_equiv opp_id  \
# 930               0     WSC      Capitols   71      47.07    BLB
# 931               0     BLB     Baltimore   95      46.41    WSC
# 1084              1     WSC      Capitols   70      47.71    CHS
# 1085              1     CHS         Stags   74      46.09    WSC
# 1088              1     BLB     Baltimore   75      50.04    CHS
# ...             ...     ...           ...  ...        ...    ...
# 122207            0     ATL         Hawks  110      39.24    BRK
# 123916            0     HOU       Rockets  113      54.89    MIN
# 123917            0     MIN  Timberwolves  101      40.13    HOU
# 124862            0     MIL         Bucks   95      41.14    NYK
# 124863            0     NYK        Knicks   79      21.19    MIL
#
#             opp_fran  opp_pts location result  forecast  \
# 930        Baltimore       95        A      L      0.41
# 931         Capitols       71        H      W      0.59
# 1084           Stags       74        A      L      0.39
# 1085        Capitols       70        H      W      0.61
# 1088           Stags       72        A      W      0.40
# ...              ...      ...      ...    ...       ...
# 122207          Nets      127        N      L      0.57
# 123916  Timberwolves      101        N      W      0.68
# 123917       Rockets      113        N      L      0.32
# 124862        Knicks       79        N      W      0.75
# 124863         Bucks       95        N      L      0.25
#
#                                             notes  pts_diff  data_game
# 930          at Baltimore's Fifth Regiment Armory        24 1948-01-30
# 931          at Baltimore's Fifth Regiment Armory        24 1948-01-30
# 1084                                   Tiebreaker         4 1948-03-23
# 1085                                   Tiebreaker         4 1948-03-23
# 1088                                   Tiebreaker         3 1948-03-25
# ...                                           ...       ...        ...
# 122207                         at London, England        17 2014-01-16
# 123916  at Mexico City Arena, Mexico City, Mexico        12 2014-11-12
# 123917  at Mexico City Arena, Mexico City, Mexico        12 2014-11-12
# 124862                 at The O2, London, England        16 2015-01-15
# 124863                 at The O2, London, England        16 2015-01-15
#
# [5424 rows x 20 columns]

# %%
nba.dropna(axis=1)
# Out:
#         gameorder       game_id  _iscopy  year_id  date_game  seasongame  \
# 0               1  194611010TRH        0     1947  11/1/1946           1
# 1               1  194611010TRH        1     1947  11/1/1946           1
# 2               2  194611020CHS        0     1947  11/2/1946           1
# 3               2  194611020CHS        1     1947  11/2/1946           2
# 4               3  194611020DTF        0     1947  11/2/1946           1
# ...           ...           ...      ...      ...        ...         ...
# 126309      63155  201506110CLE        0     2015  6/11/2015         100
# 126310      63156  201506140GSW        0     2015  6/14/2015         102
# 126311      63156  201506140GSW        1     2015  6/14/2015         101
# 126312      63157  201506170CLE        0     2015  6/16/2015         102
# 126313      63157  201506170CLE        1     2015  6/16/2015         103
#
#         is_playoffs team_id    fran_id  pts  win_equiv opp_id   opp_fran  \
# 0                 0     TRH    Huskies   66      40.29    NYK     Knicks
# 1                 0     NYK     Knicks   68      41.71    TRH    Huskies
# 2                 0     CHS      Stags   63      42.01    NYK     Knicks
# 3                 0     NYK     Knicks   47      40.69    CHS      Stags
# 4                 0     DTF    Falcons   33      38.86    WSC   Capitols
# ...             ...     ...        ...  ...        ...    ...        ...
# 126309            1     CLE  Cavaliers   82      60.31    GSW   Warriors
# 126310            1     GSW   Warriors  104      68.01    CLE  Cavaliers
# 126311            1     CLE  Cavaliers   91      60.01    GSW   Warriors
# 126312            1     CLE  Cavaliers   97      59.29    GSW   Warriors
# 126313            1     GSW   Warriors  105      68.52    CLE  Cavaliers
#
#         opp_pts location result  forecast  pts_diff  data_game
# 0            68        H      L      0.64         2 1946-11-01
# 1            66        A      W      0.36         2 1946-11-01
# 2            47        H      W      0.63        16 1946-11-02
# 3            63        A      L      0.37        16 1946-11-02
# 4            50        H      L      0.64        17 1946-11-02
# ...         ...      ...    ...       ...       ...        ...
# 126309      103        H      L      0.55        21 2015-06-11
# 126310       91        H      W      0.77        13 2015-06-14
# 126311      104        A      L      0.23        13 2015-06-14
# 126312      105        H      L      0.48         8 2015-06-16
# 126313       97        A      W      0.52         8 2015-06-16
#
# [126314 rows x 19 columns]

# %%
nba['notes'].fillna(value="No notes", inplace=True)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   _iscopy      126314 non-null  int64
#  3   year_id      126314 non-null  int64
#  4   date_game    126314 non-null  object
#  5   seasongame   126314 non-null  int64
#  6   is_playoffs  126314 non-null  int64
#  7   team_id      126314 non-null  object
#  8   fran_id      126314 non-null  object
#  9   pts          126314 non-null  int64
#  10  win_equiv    126314 non-null  float64
#  11  opp_id       126314 non-null  object
#  12  opp_fran     126314 non-null  object
#  13  opp_pts      126314 non-null  int64
#  14  location     126314 non-null  category
#  15  result       126314 non-null  object
#  16  forecast     126314 non-null  float64
#  17  notes        126314 non-null  object
#  18  pts_diff     126314 non-null  int64
#  19  data_game    126314 non-null  datetime64[ns]
# dtypes: category(1), datetime64[ns](1), float64(2), int64(8), object(8)
# memory usage: 18.4+ MB

# %%
nba.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#        win_equiv    opp_pts   forecast   pts_diff
# count  126314.00  126314.00  126314.00  126314.00
# mean       41.71     102.73       0.50      10.76
# std        10.63      14.81       0.22       7.94
# min        10.15       0.00       0.02       1.00
# 25%        34.10      93.00       0.33       5.00
# 50%        42.11     103.00       0.50       9.00
# 75%        49.64     112.00       0.67      15.00
# max        71.11     186.00       0.98      68.00

# %%
nba[nba['pts']==0]
# Out:
#        gameorder       game_id  _iscopy  year_id   date_game  seasongame  \
# 26684      13343  197210260VIR        1     1973  10/26/1972           7
#
#        is_playoffs team_id  fran_id  pts  win_equiv opp_id opp_fran  opp_pts  \
# 26684            0     DNR  Nuggets    0      40.41    VIR  Squires        2
#
#       location result  forecast                           notes  pts_diff  \
# 26684        A      L      0.33  at Richmond VA; forfeit to VIR         2
#
#        data_game
# 26684 1972-10-26

# %%
nba = nba[nba['pts']!=0]

# %%
nba[(nba["pts"] > nba["opp_pts"]) & (nba['result'] != "W")].empty
# Out:
# True

# %%
city_data
# Out:
#              revenue  manager_count
# pemalang       58790           15.0
# purbalingga    20000            NaN
# solo             710            5.0

# %%
provinsi_city = pd.DataFrame(
    {
    "provinsi" :["Jateng","Bali", "Jabar","jatim","sumatra","NTT"],
    "ibukotaprop":[0,1,1,1,0,1]
    },
index = ["pemalang","purbalingga","semarang","solo","bandung","surabaya"]
)

# %%
provinsi_city
# Out:
#             provinsi  ibukotaprop
# pemalang      Jateng            0
# purbalingga     Bali            1
# semarang       Jabar            1
# solo           jatim            1
# bandung      sumatra            0
# surabaya         NTT            1

# %%
pd.concat([city_data, provinsi_city],axis=1)
# Out:
#              revenue  manager_count provinsi  ibukotaprop
# pemalang     58790.0           15.0   Jateng            0
# purbalingga  20000.0            NaN     Bali            1
# solo           710.0            5.0    jatim            1
# semarang         NaN            NaN    Jabar            1
# bandung          NaN            NaN  sumatra            0
# surabaya         NaN            NaN      NTT            1

# %%
pd.concat([city_data, provinsi_city],axis=1, join="inner")
# Out:
#              revenue  manager_count provinsi  ibukotaprop
# pemalang       58790           15.0   Jateng            0
# purbalingga    20000            NaN     Bali            1
# solo             710            5.0    jatim            1

# %%
provinsi_city.reset_index(inplace=True)

# %%
provinsi_city.columns = ["kota","provinsi","ibukotaprop"]

# %%
provinsi_city
# Out:
#           kota provinsi  ibukotaprop
# 0     pemalang   Jateng            0
# 1  purbalingga     Bali            1
# 2     semarang    Jabar            1
# 3         solo    jatim            1
# 4      bandung  sumatra            0
# 5     surabaya      NTT            1

# %%
city_data
# Out:
#              revenue  manager_count
# pemalang       58790           15.0
# purbalingga    20000            NaN
# solo             710            5.0

# %%
city_data.reset_index(inplace=True)

# %%
city_data.columns = ["kota","revenue","manager_count"]

# %%
city_data
# Out:
#           kota  revenue  manager_count
# 0     pemalang    58790           15.0
# 1  purbalingga    20000            NaN
# 2         solo      710            5.0

# %%
pd.merge(left=city_data,right=provinsi_city,how='right',left_on='kota',right_on='kota')
# Out:
#           kota  revenue  manager_count provinsi  ibukotaprop
# 0     pemalang  58790.0           15.0   Jateng            0
# 1  purbalingga  20000.0            NaN     Bali            1
# 2     semarang      NaN            NaN    Jabar            1
# 3         solo    710.0            5.0    jatim            1
# 4      bandung      NaN            NaN  sumatra            0
# 5     surabaya      NaN            NaN      NTT            1

# %%
# %matplotlib inline

# %%
nba.dropna()
# Out:
#         gameorder       game_id  _iscopy  year_id  date_game  seasongame  \
# 0               1  194611010TRH        0     1947  11/1/1946           1
# 1               1  194611010TRH        1     1947  11/1/1946           1
# 2               2  194611020CHS        0     1947  11/2/1946           1
# 3               2  194611020CHS        1     1947  11/2/1946           2
# 4               3  194611020DTF        0     1947  11/2/1946           1
# ...           ...           ...      ...      ...        ...         ...
# 126309      63155  201506110CLE        0     2015  6/11/2015         100
# 126310      63156  201506140GSW        0     2015  6/14/2015         102
# 126311      63156  201506140GSW        1     2015  6/14/2015         101
# 126312      63157  201506170CLE        0     2015  6/16/2015         102
# 126313      63157  201506170CLE        1     2015  6/16/2015         103
#
#         is_playoffs team_id    fran_id  pts  win_equiv opp_id   opp_fran  \
# 0                 0     TRH    Huskies   66      40.29    NYK     Knicks
# 1                 0     NYK     Knicks   68      41.71    TRH    Huskies
# 2                 0     CHS      Stags   63      42.01    NYK     Knicks
# 3                 0     NYK     Knicks   47      40.69    CHS      Stags
# 4                 0     DTF    Falcons   33      38.86    WSC   Capitols
# ...             ...     ...        ...  ...        ...    ...        ...
# 126309            1     CLE  Cavaliers   82      60.31    GSW   Warriors
# 126310            1     GSW   Warriors  104      68.01    CLE  Cavaliers
# 126311            1     CLE  Cavaliers   91      60.01    GSW   Warriors
# 126312            1     CLE  Cavaliers   97      59.29    GSW   Warriors
# 126313            1     GSW   Warriors  105      68.52    CLE  Cavaliers
#
#         opp_pts location result  forecast     notes  pts_diff  data_game
# 0            68        H      L      0.64  No notes         2 1946-11-01
# 1            66        A      W      0.36  No notes         2 1946-11-01
# 2            47        H      W      0.63  No notes        16 1946-11-02
# 3            63        A      L      0.37  No notes        16 1946-11-02
# 4            50        H      L      0.64  No notes        17 1946-11-02
# ...         ...      ...    ...       ...       ...       ...        ...
# 126309      103        H      L      0.55  No notes        21 2015-06-11
# 126310       91        H      W      0.77  No notes        13 2015-06-14
# 126311      104        A      L      0.23  No notes        13 2015-06-14
# 126312      105        H      L      0.48  No notes         8 2015-06-16
# 126313       97        A      W      0.52  No notes         8 2015-06-16
#
# [126313 rows x 20 columns]

# %%
df[
    (df["team_id"] == "BOS") &
    (df["year_id"] > 2000)
].groupby(["year_id"])["pts"].mean().plot()
# Out:
# <Axes: xlabel='year_id'>

# %%
nba["fran_id"].value_counts().head(10).plot(kind="pie")
# Out:
# <Axes: ylabel='fran_id'>

# %%
nba["fran_id"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: >
