# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('Canada.xlsx', sheet_name='Canada by Citizenship (2)')

# %%
data
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
# 195  Immigrants  Foreigners         Unknown   999    World   999
#
#              RegName  DEV             DevName   1980  ...  2004  2005  2006  \
# 0      Southern Asia  902  Developing regions     16  ...  2978  3436  3009
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 43 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Type      196 non-null    object
#  1   Coverage  196 non-null    object
#  2   OdName    196 non-null    object
#  3   AREA      196 non-null    int64
#  4   AreaName  196 non-null    object
#  5   REG       196 non-null    int64
#  6   RegName   196 non-null    object
#  7   DEV       196 non-null    int64
#  8   DevName   196 non-null    object
#  9   1980      196 non-null    int64
#  10  1981      196 non-null    int64
#  11  1982      196 non-null    int64
#  12  1983      196 non-null    int64
#  13  1984      196 non-null    int64
#  14  1985      196 non-null    int64
#  15  1986      196 non-null    int64
#  16  1987      196 non-null    int64
#  17  1988      196 non-null    int64
#  18  1989      196 non-null    int64
#  19  1990      196 non-null    int64
# ...

# %%
data.isna().sum()
# Out:
# Type        0
# Coverage    0
# OdName      0
# AREA        0
# AreaName    0
# REG         0
# RegName     0
# DEV         0
# DevName     0
# 1980        0
# 1981        0
# 1982        0
# 1983        0
# 1984        0
# 1985        0
# 1986        0
# 1987        0
# 1988        0
# 1989        0
# 1990        0
# 1991        0
# 1992        0
# 1993        0
# 1994        0
# 1995        0
# 1996        0
# 1997        0
# 1998        0
# 1999        0
# 2000        0
# 2001        0
# 2002        0
# 2003        0
# 2004        0
# 2005        0
# 2006        0
# 2007        0
# 2008        0
# 2009        0
# 2010        0
# 2011        0
# 2012        0
# 2013        0
# dtype: int64

# %%
data.drop(['Type','Coverage','AREA','REG','DEV'],axis=1, inplace=True)

# %%
data.rename(columns={'OdName':'Country','AreaName':'Continent', 'RegName':'Region'}, inplace=True)

# %%
data.describe()
# Out:
#                1980          1981          1982          1983          1984  \
# count    196.000000    196.000000    196.000000    196.000000    196.000000
# mean     730.290816    656.331633    618.239796    455.025510    450.367347
# std     3664.971286   2484.869895   2198.843498   1529.175952   1580.492649
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%       13.500000     10.000000     11.500000     12.000000     13.500000
# 75%      263.000000    296.750000    292.250000    181.250000    189.000000
# max    44000.000000  24796.000000  20620.000000  13635.000000  14855.000000
#
#                1985          1986          1987          1988          1989  \
# count    196.000000    196.000000    196.000000    196.000000    196.000000
# mean     430.336735    506.892857    775.892857    824.413265    977.295918
# ...

# %%
data.groupby(['Continent'])[[1980,1981]].mean()
# Out:
#                                          1980          1981
# Continent
# Africa                              73.166667     80.796296
# Asia                               633.163265    700.285714
# Europe                             924.651163   1041.906977
# Latin America and the Caribbean    396.393939    461.060606
# Northern America                  4689.000000   5015.000000
# Oceania                            138.714286    131.357143
# World                            44000.000000  18078.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
mpl.style.use(['ggplot'])

# %%
years = list(range(1980,2014))

# %%
data.set_index('Country',inplace=True)

# %%
data.loc['Afghanistan',years].plot()

plt.title('Immigration from Afghanistan to Canada')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
haiti = data.loc['Haiti', years]
haiti.plot()
# Out:
# <Axes: >

# %%
haiti.values
# Out:
# array([1666, 3692, 3498, 2860, 1418, 1321, 1753, 2132, 1829, 2377, 2379,
#        2829, 2399, 3655, 2100, 2014, 1955, 1645, 1295, 1439, 1631, 2433,
#        2174, 1930, 1652, 1682, 1619, 1598, 2491, 2080, 4744, 6503, 5868,
#        4152], dtype=object)

# %%
plt.plot(haiti.index,haiti.values)

plt.title('Immigration from Haiti to Canada')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
plt.plot(haiti.index,haiti.values)

plt.title('Immigration from Haiti to Canada')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.text(2000, 6000, '2010 earthquake')
# Out:
# Text(2000, 6000, '2010 earthquake')

# %%
china_india = data.loc[['China','India'], years]

# %%
china_india.plot()
# Out:
# <Axes: xlabel='Country'>

# %%
china_india.transpose().plot()
plt.title('Immigration to Canada')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
data['Total'] = data[years].sum(axis=1)

# %%
data.drop('Unknown', inplace=True)

# %%
data.sort_values(by='Total', ascending=False, inplace=True)

# %%
top5 = data[years].head(5).transpose()

top5.plot(figsize=(14,8))
plt.title('Immigration to Canada')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
top5 = data[years].tail(5).transpose()

top5.plot(figsize=(14,8))
plt.title('Immigration to Canada')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
top5 = data[years].head(5).transpose()

top5.plot(kind='area',
         stacked=False,
         alpha=0.25,
         figsize=(14,8))

plt.title('Immigration to Canada')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
top5 = data[years].head(5).transpose()

top5.plot(kind='area',
         stacked=True,
         alpha=0.25,
         figsize=(14,8))

plt.title('Immigration to Canada')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
data['Total'].plot(kind='hist', figsize=(14,8))
plt.title('Histogram of Total Immigrants from 195 countries')
plt.xlabel('Number of Immigrants')
# Out:
# Text(0.5, 0, 'Number of Immigrants')

# %%
# canada_data['Total']

count, bin_edges = np.histogram(data['Total'])

data['Total'].plot(kind='hist', figsize=(14,8), xticks=bin_edges)
plt.title('Histogram of Total Immigrants from 195 countries')
plt.xlabel('Number of Immigrants')
# Out:
# Text(0.5, 0, 'Number of Immigrants')

# %%
# canada_data['Total']

n=20
count, bin_edges = np.histogram(data['Total'], bins=20)

data['Total'].plot(kind='hist', figsize=(14,8), xticks=bin_edges)
plt.title('Histogram of Total Immigrants from 195 countries')
plt.xlabel('Number of Immigrants')
# Out:
# Text(0.5, 0, 'Number of Immigrants')

# %%
count, bin_edges = np.histogram(data[[1980,1990,2000,2010]], 15)

data[[1980,1990,2000,2010]].plot(
    kind='hist',
    alpha=0.25,
    bins=15,
    xticks=bin_edges,
    figsize=(14,8)
)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.loc[['Denmark','Norway','Sweden'], years].transpose().plot(
    kind='hist',
    alpha=0.25,
    bins=15,
    #xticks=bin_edges,
    figsize=(14,8)
)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iceland = data.loc['Iceland',years]
iceland.head()
# Out:
# 1980    17
# 1981    33
# 1982    10
# 1983     9
# 1984    13
# Name: Iceland, dtype: object

# %%
iceland.plot(kind='bar',figsize=(14,8))
plt.title('Icelandic Immigrants to Canda from 1980 to 2013')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')


plt.annotate(
    '',
    xy=(32,70),
    xytext=(28,15),
    xycoords='data',
    arrowprops=dict(arrowstyle='->',connectionstyle='arc3',color='blue',lw=2)
)

plt.annotate(
    'Something Happened',
    xy=(29,40),
#     xytext=(28,15),
    xycoords='data',
    rotation=72.5,
    va='bottom',
    ha='left'
    
)
# Out:
# Text(29, 40, 'Something Happened')

# %%
data['Total'].head(10).sort_values(ascending=True).plot(kind='barh',figsize=(14,8))
# Out:
# <Axes: ylabel='Country'>

# %%
data
# Out:
#                                                    Continent  \
# Country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
# ...                                                      ...
# San Marino                                            Europe
# New Caledonia                                        Oceania
# Marshall Islands                                     Oceania
# Western Sahara                                        Africa
# Palau                                                Oceania
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# ...

# %%
# df_continents = data.
df_continents = data.groupby('Continent', axis=0).sum()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_9096\2062573753.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_continents = data.groupby('Continent', axis=0).sum()

# %%
df_continents
# Out:
#                                   1980   1981   1982   1983   1984   1985  \
# Continent
# Africa                            3951   4363   3819   2671   2639   2650
# Asia                             31025  34314  30214  24696  27274  23850
# Europe                           39760  44802  42720  24638  22287  20844
# Latin America and the Caribbean  13081  15215  16769  15427  13678  15171
# Northern America                  9378  10030   9074   7100   6661   6543
# Oceania                           1942   1839   1675   1018    878    920
#
#                                   1986   1987   1988   1989  ...    2005  \
# Continent                                                    ...
# Africa                            3782   7494   7552   9894  ...   27523
# Asia                             28739  43203  47454  60256  ...  159253
# Europe                           24370  46698  54726  60893  ...   35955
# Latin America and the Caribbean  21179  28471  21924  25060  ...   24747
# ...

# %%
df_continents.loc['Asia',years].plot()
df_continents.loc['Europe',years].plot()
# Out:
# <Axes: >

# %%
df_continents['Total'].plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Total'>

# %%
explode_list=[0.1,0,0,0,0.1,0.1]
df_continents['Total'].plot(
    kind='pie',
    autopct='%1.1f%%',
    labels= None,
    pctdistance=1.12,
    explode=explode_list,
    figsize=(14,8)
)

plt.title('Immigration to Canada by Continent[1980-2013]')

plt.axis('equal')
plt.legend(labels=df_continents.index,loc='upper left')

# %%
data.loc[['Denmark','Norway','Sweden'], years].transpose().plot(kind='box')
plt.title('Immigration to Canada from Denmark,Norway, and Sweden')

#plt.axis('equal')
#plt.legend(labels=df_continents.index,loc='upper left')
# Out:
# Text(0.5, 1.0, 'Immigration to Canada from Denmark,Norway, and Sweden')

# %%
data.loc[['China','India'], years].transpose().plot(kind='box', vert=False)
# plt.title("Immigration to Canada from Denmark, Norway, and Sweden")
# Out:
# <Axes: >

# %%
fig = plt.figure()

ax0 = fig.add_subplot(1,2,1)
ax1 = fig.add_subplot(1,2,2)

data.loc[['China','India'], years].transpose().plot(kind='box', vert=False, figsize=(20,6), ax=ax0)
ax0.set_title('Boxplot')
ax0.set_ylabel('Country')
ax0.set_xlabel('Number of Immigrants')

china_india.transpose().plot(kind='line', figsize=(20,6), ax=ax1)
ax1.set_title('Line')
ax1.set_ylabel('Number of Immigrants')
ax1.set_xlabel('Years')

#plt.title('A')
# Out:
# Text(0.5, 0, 'Years')

# %%
fig = plt.figure()

ax0 = fig.add_subplot(2,2,1)
ax1 = fig.add_subplot(2,2,4)

data.loc[['China','India'], years].transpose().plot(kind='box',figsize=(6,10),vert=False, ax=ax0)
ax0.set_title('Boxplot')
ax0.set_ylabel('Country')
ax0.set_xlabel('Number of Immigrants')

china_india.transpose().plot(kind='line', figsize=(6,10), ax=ax1)
ax1.set_title('Line')
ax1.set_ylabel('Number of Immigrants')
ax1.set_xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
x = np.random.random(100)
y = np.random.random(100)

# %%
x
# Out:
# array([0.49339538, 0.93624774, 0.43702454, 0.39158697, 0.35017662,
#        0.72210454, 0.75490676, 0.77810747, 0.08616245, 0.37560213,
#        0.31364945, 0.96097648, 0.45345095, 0.84993905, 0.01040104,
#        0.31000693, 0.33731488, 0.20626527, 0.04070162, 0.16737831,
#        0.05346687, 0.40297772, 0.61864745, 0.083219  , 0.56975487,
#        0.9110911 , 0.60249435, 0.90547033, 0.28223702, 0.00949633,
#        0.2487683 , 0.61434248, 0.20109784, 0.41772927, 0.0320336 ,
#        0.80710328, 0.0673734 , 0.47905379, 0.40395062, 0.15559054,
#        0.42611719, 0.22431695, 0.10048049, 0.41094623, 0.1085056 ,
#        0.63612639, 0.57182517, 0.65226188, 0.94693369, 0.26375158,
#        0.37126191, 0.61365297, 0.90228363, 0.10682523, 0.19413841,
#        0.0534648 , 0.56839237, 0.97128623, 0.74824649, 0.87056556,
#        0.14461751, 0.82481304, 0.9162727 , 0.91179691, 0.04889466,
#        0.56963468, 0.99152656, 0.44982431, 0.7873368 , 0.21617219,
# ...

# %%
y
# Out:
# array([0.89563061, 0.69642025, 0.5716276 , 0.69328392, 0.38728104,
#        0.01164454, 0.78542417, 0.67692791, 0.64801223, 0.87516002,
#        0.86704263, 0.88639018, 0.14272744, 0.41021257, 0.09916975,
#        0.41811777, 0.78370435, 0.79971278, 0.94314849, 0.4428016 ,
#        0.35572389, 0.31964842, 0.14857328, 0.48419321, 0.48976801,
#        0.68568265, 0.32211523, 0.31491391, 0.75806569, 0.93578823,
#        0.6188942 , 0.43952626, 0.3841414 , 0.84388433, 0.73197571,
#        0.86649863, 0.69423066, 0.65160695, 0.86434347, 0.94513972,
#        0.03988368, 0.08748409, 0.83411643, 0.7963196 , 0.08094741,
#        0.65480461, 0.02349502, 0.2632308 , 0.09741326, 0.67491125,
#        0.47158662, 0.18063596, 0.88258811, 0.94015122, 0.40805598,
#        0.84684159, 0.69398637, 0.24243149, 0.23756568, 0.22139294,
#        0.93484316, 0.68712471, 0.79257248, 0.35260152, 0.19142842,
#        0.80237474, 0.62607136, 0.17679024, 0.1871069 , 0.32044445,
# ...

# %%
np.random.normal()
# Out:
# -0.4725935934830167

# %%
d = pd.DataFrame({'x':x, 'y':x*2+10*np.random.normal()})

# %%
d.plot(kind='scatter', x='x', y='y', figsize=(10,10))
# Out:
# <Axes: xlabel='x', ylabel='y'>
